# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.core.pylabtools import figsize
import numpy as np
from matplotlib import pyplot as plta
figsize(11, 9)
import scipy.stats as stats

# %%
dist  = stats.beta
n_test = [0, 1, 2, 3, 4, 5, 8, 15, 50, 500]
x = np.linspace(0,1,100)
for k ,N in enumerate(n_test):
    sx = plt.subplot(len(n_test)/2, 2 ,k+1 )
    
    plt.xlabel("$p$, probability of heads") if k in [0, len(n_trials)-1] else None
    plt.setp(sx.get_yticklabels(), visible=False)
    heads = data[:N].sum()
    
    y = dist.pdf(x, 1+heads , 1+N-heads)
    plt.plot(x, y , label="observe %d tosses,\n %d heads" % (N, heads))
    plt.fill_between(x, 0, y, color="#348ABD", alpha=0.4)
    plt.vlines(0.5, 0, 4, color="k", linestyles="--", lw=1)

    leg = plt.legend()
    leg.get_frame().set_alpha(0.4)
    plt.autoscale(tight=True)

# %% [markdown]
# On note que les figures ne sont pas toujours centrés sur 0.5. Par exemple 4 pieces lancer, on a obtenue 3 piles.
# C'est apres qu'on ait fait plusierus expériences que la probabilité se concentre sur 0.5.
